# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings 
import sqlite3
from datetime import datetime
import os 
warnings.filterwarnings('ignore')

# %%
import seaborn as sns

# %%
data = pd.read_csv('Cost of a healthy diet.csv')
data2 = pd.read_csv('GDP per capita.csv')
data3 = pd.read_csv('Number of undernourished people.csv')
data4 = pd.read_csv('Unable to afford healthy diet.csv')

# %%
data.head()
# Out:
#   FREQ FREQ_LABEL REF_AREA        REF_AREA_LABEL      INDICATOR  \
# 0    A     Annual      ABW                 Aruba  FAO_CAHD_7004
# 1    A     Annual      AGO                Angola  FAO_CAHD_7004
# 2    A     Annual      ALB               Albania  FAO_CAHD_7004
# 3    A     Annual      ARE  United Arab Emirates  FAO_CAHD_7004
# 4    A     Annual      ARG             Argentina  FAO_CAHD_7004
#
#                                      INDICATOR_LABEL UNIT_MEASURE  \
# 0  Cost of a healthy diet (PPP dollar per person ...     PPP_PS_D
# 1  Cost of a healthy diet (PPP dollar per person ...     PPP_PS_D
# 2  Cost of a healthy diet (PPP dollar per person ...     PPP_PS_D
# 3  Cost of a healthy diet (PPP dollar per person ...     PPP_PS_D
# 4  Cost of a healthy diet (PPP dollar per person ...     PPP_PS_D
#
#                UNIT_MEASURE_LABEL DATABASE_ID  \
# 0  PPP dollars per person per day    FAO_CAHD
# 1  PPP dollars per person per day    FAO_CAHD
# ...

# %%
filtered_data = data[data["REF_AREA_LABEL"]=="Zambia"]
filtered_data.head()
# Out:
#     FREQ FREQ_LABEL REF_AREA REF_AREA_LABEL      INDICATOR  \
# 173    A     Annual      ZMB         Zambia  FAO_CAHD_7004
#
#                                        INDICATOR_LABEL UNIT_MEASURE  \
# 173  Cost of a healthy diet (PPP dollar per person ...     PPP_PS_D
#
#                  UNIT_MEASURE_LABEL DATABASE_ID  \
# 173  PPP dollars per person per day    FAO_CAHD
#
#                                     DATABASE_ID_LABEL  ...  OBS_STATUS  \
# 173  Cost and Affordability of a Healthy Diet (CoAHD)  ...           A
#
#     OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL  2017  2018  2019  2020  2021  \
# 173     Normal value       PU         Public  2.73  2.79  2.88  2.92   3.2
#
#      2022
# 173  3.53
#
# [1 rows x 22 columns]

# %%
data2.head()
# Out:
#   FREQ FREQ_LABEL REF_AREA        REF_AREA_LABEL     INDICATOR  \
# 0    A     Annual      AFG           Afghanistan  FAO_FS_22013
# 1    A     Annual      AGO                Angola  FAO_FS_22013
# 2    A     Annual      ALB               Albania  FAO_FS_22013
# 3    A     Annual      AND               Andorra  FAO_FS_22013
# 4    A     Annual      ARE  United Arab Emirates  FAO_FS_22013
#
#                                      INDICATOR_LABEL UNIT_MEASURE  \
# 0  Gross domestic product per capita, PPP, (const...  INT_USD_CAP
# 1  Gross domestic product per capita, PPP, (const...  INT_USD_CAP
# 2  Gross domestic product per capita, PPP, (const...  INT_USD_CAP
# 3  Gross domestic product per capita, PPP, (const...  INT_USD_CAP
# 4  Gross domestic product per capita, PPP, (const...  INT_USD_CAP
#
#                 UNIT_MEASURE_LABEL DATABASE_ID  \
# 0  International Dollar per capita      FAO_FS
# 1  International Dollar per capita      FAO_FS
# ...

# %%
filtered_data2 = data2[data2["REF_AREA_LABEL"]=="Zambia"]
filtered_data2.head()
# Out:
#     FREQ FREQ_LABEL REF_AREA REF_AREA_LABEL     INDICATOR  \
# 187    A     Annual      ZMB         Zambia  FAO_FS_22013
#
#                                        INDICATOR_LABEL UNIT_MEASURE  \
# 187  Gross domestic product per capita, PPP, (const...  INT_USD_CAP
#
#                   UNIT_MEASURE_LABEL DATABASE_ID  \
# 187  International Dollar per capita      FAO_FS
#
#                      DATABASE_ID_LABEL  ...    2015    2016    2017    2018  \
# 187  Suite of Food Security Indicators  ...  3576.9  3598.2  3612.5  3647.0
#
#        2019    2020    2021    2022    2023    2024
# 187  3591.6  3391.6  3503.0  3585.1  3673.5  3716.0
#
# [1 rows x 41 columns]

# %%
data.describe()
# Out:
#        UNIT_MULT        2017        2018        2019        2020        2021  \
# count      175.0  172.000000  168.000000  168.000000  168.000000  173.000000
# mean         0.0    3.137151    3.182738    3.267619    3.367024    3.576012
# std          0.0    0.657576    0.673173    0.678186    0.687685    0.766418
# min          0.0    1.470000    1.490000    1.530000    1.860000    1.930000
# 25%          0.0    2.657500    2.725000    2.810000    2.885000    3.040000
# 50%          0.0    3.075000    3.105000    3.180000    3.280000    3.440000
# 75%          0.0    3.502500    3.555000    3.662500    3.732500    3.950000
# max          0.0    5.480000    5.650000    5.570000    5.800000    5.910000
#
#              2022
# count  168.000000
# mean     3.960595
# std      0.865485
# min      1.860000
# 25%      3.420000
# 50%      3.815000
# 75%      4.492500
# max      6.760000

# %%
filtered_data3 = data3[data3["REF_AREA_LABEL"]=="Zambia"]
filtered_data3.head()
# Out:
#     FREQ FREQ_LABEL REF_AREA REF_AREA_LABEL      INDICATOR  \
# 118    A     Annual      ZMB         Zambia  FAO_FS_210011
#
#                                        INDICATOR_LABEL UNIT_MEASURE  \
# 118  Number of people undernourished (million) (3-y...        COUNT
#
#     UNIT_MEASURE_LABEL DATABASE_ID                  DATABASE_ID_LABEL  ...  \
# 118              Count      FAO_FS  Suite of Food Security Indicators  ...
#
#      2015 2016 2017 2018 2019 2020  2021  2022  2023  2024
# 118   5.9  5.8  5.7  5.5  5.7  5.9   6.5   7.0   7.3   7.7
#
# [1 rows x 39 columns]

# %%
filtered_data4 = data4[data4["REF_AREA_LABEL"]=="Zambia"]
filtered_data4.head()
# Out:
#     FREQ FREQ_LABEL REF_AREA REF_AREA_LABEL      INDICATOR  \
# 144    A     Annual      ZMB         Zambia  FAO_CAHD_7006
#
#                                        INDICATOR_LABEL UNIT_MEASURE  \
# 144  Number of people unable to afford a healthy di...           PS
#
#     UNIT_MEASURE_LABEL DATABASE_ID  \
# 144            Persons    FAO_CAHD
#
#                                     DATABASE_ID_LABEL  ...  OBS_CONF  \
# 144  Cost and Affordability of a Healthy Diet (CoAHD)  ...        PU
#
#     OBS_CONF_LABEL  2017  2018  2019  2020  2021  2022  2023  2024
# 144         Public  13.6  14.0  14.6  15.3  15.9  16.5  17.0  17.5
#
# [1 rows x 24 columns]

# %%
missing_values = filtered_data.isnull().sum()
missing_values
# Out:
# FREQ                  0
# FREQ_LABEL            0
# REF_AREA              0
# REF_AREA_LABEL        0
# INDICATOR             0
# INDICATOR_LABEL       0
# UNIT_MEASURE          0
# UNIT_MEASURE_LABEL    0
# DATABASE_ID           0
# DATABASE_ID_LABEL     0
# UNIT_MULT             0
# UNIT_MULT_LABEL       0
# OBS_STATUS            0
# OBS_STATUS_LABEL      0
# OBS_CONF              0
# OBS_CONF_LABEL        0
# 2017                  0
# 2018                  1
# 2019                  1
# 2020                  1
# 2021                  1
# 2022                  1
# dtype: int64

# %%
missing_values = filtered_data2.isnull().sum()
missing_values
# Out:
# FREQ                  0
# FREQ_LABEL            0
# REF_AREA              0
# REF_AREA_LABEL        0
# INDICATOR             0
# INDICATOR_LABEL       0
# UNIT_MEASURE          0
# UNIT_MEASURE_LABEL    0
# DATABASE_ID           0
# DATABASE_ID_LABEL     0
# UNIT_MULT             0
# UNIT_MULT_LABEL       0
# OBS_STATUS            0
# OBS_STATUS_LABEL      0
# OBS_CONF              0
# OBS_CONF_LABEL        0
# 2000                  0
# 2001                  0
# 2002                  0
# 2003                  0
# 2004                  0
# 2005                  0
# 2006                  0
# 2007                  0
# 2008                  0
# 2009                  0
# 2010                  0
# 2011                  0
# 2012                  0
# 2013                  0
# 2014                  0
# 2015                  0
# 2016                  0
# 2017                  0
# 2018                  0
# 2019                  0
# 2020                  0
# 2021                  0
# ...

# %%
missing_values = filtered_data3.isnull().sum()
missing_values
# Out:
# FREQ                  0
# FREQ_LABEL            0
# REF_AREA              0
# REF_AREA_LABEL        0
# INDICATOR             0
# INDICATOR_LABEL       0
# UNIT_MEASURE          0
# UNIT_MEASURE_LABEL    0
# DATABASE_ID           0
# DATABASE_ID_LABEL     0
# UNIT_MULT             0
# UNIT_MULT_LABEL       0
# OBS_STATUS            0
# OBS_STATUS_LABEL      0
# OBS_CONF              0
# OBS_CONF_LABEL        0
# 2002                  0
# 2003                  0
# 2004                  0
# 2005                  0
# 2006                  0
# 2007                  0
# 2008                  0
# 2009                  0
# 2010                  0
# 2011                  0
# 2012                  0
# 2013                  0
# 2014                  0
# 2015                  0
# 2016                  0
# 2017                  0
# 2018                  0
# 2019                  0
# 2020                  0
# 2021                  0
# 2022                  0
# 2023                  0
# ...

# %%
missing_values = filtered_data4.isnull().sum()
missing_values
# Out:
# FREQ                  0
# FREQ_LABEL            0
# REF_AREA              0
# REF_AREA_LABEL        0
# INDICATOR             0
# INDICATOR_LABEL       0
# UNIT_MEASURE          0
# UNIT_MEASURE_LABEL    0
# DATABASE_ID           0
# DATABASE_ID_LABEL     0
# UNIT_MULT             0
# UNIT_MULT_LABEL       0
# OBS_STATUS            0
# OBS_STATUS_LABEL      0
# OBS_CONF              0
# OBS_CONF_LABEL        0
# 2017                  0
# 2018                  1
# 2019                  1
# 2020                  1
# 2021                  1
# 2022                  1
# 2023                  1
# 2024                  1
# dtype: int64

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# FREQ                  0
# FREQ_LABEL            0
# REF_AREA              0
# REF_AREA_LABEL        0
# INDICATOR             0
# INDICATOR_LABEL       0
# UNIT_MEASURE          0
# UNIT_MEASURE_LABEL    0
# DATABASE_ID           0
# DATABASE_ID_LABEL     0
# UNIT_MULT             0
# UNIT_MULT_LABEL       0
# OBS_STATUS            0
# OBS_STATUS_LABEL      0
# OBS_CONF              0
# OBS_CONF_LABEL        0
# 2017                  3
# 2018                  7
# 2019                  7
# 2020                  7
# 2021                  2
# 2022                  7
# dtype: int64

# %%
missing_values = data2.isnull().sum()
missing_values
# Out:
# FREQ                  0
# FREQ_LABEL            0
# REF_AREA              0
# REF_AREA_LABEL        0
# INDICATOR             0
# INDICATOR_LABEL       0
# UNIT_MEASURE          0
# UNIT_MEASURE_LABEL    0
# DATABASE_ID           0
# DATABASE_ID_LABEL     0
# UNIT_MULT             0
# UNIT_MULT_LABEL       0
# OBS_STATUS            0
# OBS_STATUS_LABEL      0
# OBS_CONF              0
# OBS_CONF_LABEL        0
# 2000                  1
# 2001                  1
# 2002                  1
# 2003                  1
# 2004                  1
# 2005                  1
# 2006                  1
# 2007                  1
# 2008                  1
# 2009                  1
# 2010                  1
# 2011                  1
# 2012                  1
# 2013                  0
# 2014                  0
# 2015                  0
# 2016                  0
# 2017                  0
# 2018                  0
# 2019                  0
# 2020                  0
# 2021                  0
# ...

# %%
missing_values = data3.isnull().sum()
missing_values
# Out:
# FREQ                   0
# FREQ_LABEL             0
# REF_AREA               0
# REF_AREA_LABEL         0
# INDICATOR              0
# INDICATOR_LABEL        0
# UNIT_MEASURE           0
# UNIT_MEASURE_LABEL     0
# DATABASE_ID            0
# DATABASE_ID_LABEL      0
# UNIT_MULT              0
# UNIT_MULT_LABEL        0
# OBS_STATUS             0
# OBS_STATUS_LABEL       0
# OBS_CONF               0
# OBS_CONF_LABEL         0
# 2002                   8
# 2003                  10
# 2004                  11
# 2005                  11
# 2006                  13
# 2007                  16
# 2008                  18
# 2009                  18
# 2010                  21
# 2011                  21
# 2012                  21
# 2013                  23
# 2014                  22
# 2015                  22
# 2016                  25
# 2017                  24
# 2018                  24
# 2019                  25
# 2020                  26
# 2021                  23
# 2022                  26
# ...

# %%
missing_values = data4.isnull().sum()
missing_values
# Out:
# FREQ                  0
# FREQ_LABEL            0
# REF_AREA              0
# REF_AREA_LABEL        0
# INDICATOR             0
# INDICATOR_LABEL       0
# UNIT_MEASURE          0
# UNIT_MEASURE_LABEL    0
# DATABASE_ID           0
# DATABASE_ID_LABEL     0
# UNIT_MULT             0
# UNIT_MULT_LABEL       0
# OBS_STATUS            0
# OBS_STATUS_LABEL      0
# OBS_CONF              0
# OBS_CONF_LABEL        0
# 2017                  1
# 2018                  4
# 2019                  6
# 2020                  7
# 2021                  7
# 2022                  7
# 2023                  5
# 2024                  9
# dtype: int64

# %%
DietCost = data[["REF_AREA_LABEL", "INDICATOR_LABEL", "UNIT_MEASURE_LABEL", "OBS_STATUS_LABEL", "2017", "2018", "2019", "2020","2021", "2022"]]

# %%
DietCost
# Out:
#              REF_AREA_LABEL  \
# 0                     Aruba
# 1                    Angola
# 2                   Albania
# 3      United Arab Emirates
# 4                 Argentina
# ..                      ...
# 170  British Virgin Islands
# 171                Viet Nam
# 172            South Africa
# 173                  Zambia
# 174                Zimbabwe
#
#                                        INDICATOR_LABEL  \
# 0    Cost of a healthy diet (PPP dollar per person ...
# 1    Cost of a healthy diet (PPP dollar per person ...
# 2    Cost of a healthy diet (PPP dollar per person ...
# 3    Cost of a healthy diet (PPP dollar per person ...
# 4    Cost of a healthy diet (PPP dollar per person ...
# ..                                                 ...
# 170  Cost of a healthy diet (PPP dollar per person ...
# 171  Cost of a healthy diet (PPP dollar per person ...
# 172  Cost of a healthy diet (PPP dollar per person ...
# 173  Cost of a healthy diet (PPP dollar per person ...
# ...

# %%
GDP_Per_Capita = data2[["REF_AREA_LABEL", "INDICATOR_LABEL", "UNIT_MEASURE_LABEL", "2017", "2018","2019", "2020","2021", "2022", "2023", "2024"]]

# %%
GDP_Per_Capita
# Out:
#            REF_AREA_LABEL                                    INDICATOR_LABEL  \
# 0             Afghanistan  Gross domestic product per capita, PPP, (const...
# 1                  Angola  Gross domestic product per capita, PPP, (const...
# 2                 Albania  Gross domestic product per capita, PPP, (const...
# 3                 Andorra  Gross domestic product per capita, PPP, (const...
# 4    United Arab Emirates  Gross domestic product per capita, PPP, (const...
# ..                    ...                                                ...
# 184               Vanuatu  Gross domestic product per capita, PPP, (const...
# 185                 Samoa  Gross domestic product per capita, PPP, (const...
# 186          South Africa  Gross domestic product per capita, PPP, (const...
# 187                Zambia  Gross domestic product per capita, PPP, (const...
# 188              Zimbabwe  Gross domestic product per capita, PPP, (const...
#
# ...

# %%
Undernourished_People = data3[["REF_AREA_LABEL", "INDICATOR_LABEL", "UNIT_MEASURE_LABEL", "2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024"]]

# %%
Undernourished_People
# Out:
#            REF_AREA_LABEL                                    INDICATOR_LABEL  \
# 0             Afghanistan  Number of people undernourished (million) (3-y...
# 1                  Angola  Number of people undernourished (million) (3-y...
# 2                 Albania  Number of people undernourished (million) (3-y...
# 3    United Arab Emirates  Number of people undernourished (million) (3-y...
# 4               Argentina  Number of people undernourished (million) (3-y...
# ..                    ...                                                ...
# 115         Venezuela, RB  Number of people undernourished (million) (3-y...
# 116              Viet Nam  Number of people undernourished (million) (3-y...
# 117          South Africa  Number of people undernourished (million) (3-y...
# 118                Zambia  Number of people undernourished (million) (3-y...
# 119              Zimbabwe  Number of people undernourished (million) (3-y...
#
# ...

# %%
Unable_To_Afford = data4[["REF_AREA_LABEL",	"INDICATOR_LABEL", "UNIT_MEASURE_LABEL", "2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024"]]

# %%
Unable_To_Afford
# Out:
#            REF_AREA_LABEL                                    INDICATOR_LABEL  \
# 0                  Angola  Number of people unable to afford a healthy di...
# 1                 Albania  Number of people unable to afford a healthy di...
# 2    United Arab Emirates  Number of people unable to afford a healthy di...
# 3               Argentina  Number of people unable to afford a healthy di...
# 4                 Armenia  Number of people unable to afford a healthy di...
# ..                    ...                                                ...
# 141            Uzbekistan  Number of people unable to afford a healthy di...
# 142              Viet Nam  Number of people unable to afford a healthy di...
# 143          South Africa  Number of people unable to afford a healthy di...
# 144                Zambia  Number of people unable to afford a healthy di...
# 145              Zimbabwe  Number of people unable to afford a healthy di...
#
# ...

# %%
#This is where we were renaming the country names from each dataset to ="COUNTRY_NAME" for easier understanding 
DietCost.rename(columns={'REF_AREA_LABEL': 'COUNTRY_NAME'}, inplace = True)

# %%
DietCost
# Out:
#                COUNTRY_NAME  \
# 0                     Aruba
# 1                    Angola
# 2                   Albania
# 3      United Arab Emirates
# 4                 Argentina
# ..                      ...
# 170  British Virgin Islands
# 171                Viet Nam
# 172            South Africa
# 173                  Zambia
# 174                Zimbabwe
#
#                                        INDICATOR_LABEL  \
# 0    Cost of a healthy diet (PPP dollar per person ...
# 1    Cost of a healthy diet (PPP dollar per person ...
# 2    Cost of a healthy diet (PPP dollar per person ...
# 3    Cost of a healthy diet (PPP dollar per person ...
# 4    Cost of a healthy diet (PPP dollar per person ...
# ..                                                 ...
# 170  Cost of a healthy diet (PPP dollar per person ...
# 171  Cost of a healthy diet (PPP dollar per person ...
# 172  Cost of a healthy diet (PPP dollar per person ...
# 173  Cost of a healthy diet (PPP dollar per person ...
# ...

# %%
DietCost.rename(columns={'Country_Name': 'COUNTRY_NAME'}, inplace = True)

# %%
DietCost
# Out:
#                COUNTRY_NAME  \
# 0                     Aruba
# 1                    Angola
# 2                   Albania
# 3      United Arab Emirates
# 4                 Argentina
# ..                      ...
# 170  British Virgin Islands
# 171                Viet Nam
# 172            South Africa
# 173                  Zambia
# 174                Zimbabwe
#
#                                        INDICATOR_LABEL  \
# 0    Cost of a healthy diet (PPP dollar per person ...
# 1    Cost of a healthy diet (PPP dollar per person ...
# 2    Cost of a healthy diet (PPP dollar per person ...
# 3    Cost of a healthy diet (PPP dollar per person ...
# 4    Cost of a healthy diet (PPP dollar per person ...
# ..                                                 ...
# 170  Cost of a healthy diet (PPP dollar per person ...
# 171  Cost of a healthy diet (PPP dollar per person ...
# 172  Cost of a healthy diet (PPP dollar per person ...
# 173  Cost of a healthy diet (PPP dollar per person ...
# ...

# %%
GDP_Per_Capita.rename(columns={'REF_AREA_LABEL': 'COUNTRY_NAME'}, inplace = True)

# %%
GDP_Per_Capita
# Out:
#              COUNTRY_NAME                                    INDICATOR_LABEL  \
# 0             Afghanistan  Gross domestic product per capita, PPP, (const...
# 1                  Angola  Gross domestic product per capita, PPP, (const...
# 2                 Albania  Gross domestic product per capita, PPP, (const...
# 3                 Andorra  Gross domestic product per capita, PPP, (const...
# 4    United Arab Emirates  Gross domestic product per capita, PPP, (const...
# ..                    ...                                                ...
# 184               Vanuatu  Gross domestic product per capita, PPP, (const...
# 185                 Samoa  Gross domestic product per capita, PPP, (const...
# 186          South Africa  Gross domestic product per capita, PPP, (const...
# 187                Zambia  Gross domestic product per capita, PPP, (const...
# 188              Zimbabwe  Gross domestic product per capita, PPP, (const...
#
# ...

# %%
Undernourished_People.rename(columns={'REF_AREA_LABEL': 'COUNTRY_NAME'}, inplace = True)

# %%
Undernourished_People
# Out:
#              COUNTRY_NAME                                    INDICATOR_LABEL  \
# 0             Afghanistan  Number of people undernourished (million) (3-y...
# 1                  Angola  Number of people undernourished (million) (3-y...
# 2                 Albania  Number of people undernourished (million) (3-y...
# 3    United Arab Emirates  Number of people undernourished (million) (3-y...
# 4               Argentina  Number of people undernourished (million) (3-y...
# ..                    ...                                                ...
# 115         Venezuela, RB  Number of people undernourished (million) (3-y...
# 116              Viet Nam  Number of people undernourished (million) (3-y...
# 117          South Africa  Number of people undernourished (million) (3-y...
# 118                Zambia  Number of people undernourished (million) (3-y...
# 119              Zimbabwe  Number of people undernourished (million) (3-y...
#
# ...

# %%
Unable_To_Afford.rename(columns={'REF_AREA_LABEL': 'COUNTRY_NAME'}, inplace = True)

# %%
Unable_To_Afford
# Out:
#              COUNTRY_NAME                                    INDICATOR_LABEL  \
# 0                  Angola  Number of people unable to afford a healthy di...
# 1                 Albania  Number of people unable to afford a healthy di...
# 2    United Arab Emirates  Number of people unable to afford a healthy di...
# 3               Argentina  Number of people unable to afford a healthy di...
# 4                 Armenia  Number of people unable to afford a healthy di...
# ..                    ...                                                ...
# 141            Uzbekistan  Number of people unable to afford a healthy di...
# 142              Viet Nam  Number of people unable to afford a healthy di...
# 143          South Africa  Number of people unable to afford a healthy di...
# 144                Zambia  Number of people unable to afford a healthy di...
# 145              Zimbabwe  Number of people unable to afford a healthy di...
#
# ...

# %%
#Gathering the datatypes of the DietCost Table
DietCost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   COUNTRY_NAME        175 non-null    object
#  1   INDICATOR_LABEL     175 non-null    object
#  2   UNIT_MEASURE_LABEL  175 non-null    object
#  3   OBS_STATUS_LABEL    175 non-null    object
#  4   2017                172 non-null    float64
#  5   2018                168 non-null    float64
#  6   2019                168 non-null    float64
#  7   2020                168 non-null    float64
#  8   2021                173 non-null    float64
#  9   2022                168 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 13.8+ KB

# %%
#Gathering the datatypes of the GDP_Per_Capita Table
GDP_Per_Capita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   COUNTRY_NAME        189 non-null    object
#  1   INDICATOR_LABEL     189 non-null    object
#  2   UNIT_MEASURE_LABEL  189 non-null    object
#  3   2017                189 non-null    float64
#  4   2018                189 non-null    float64
#  5   2019                189 non-null    float64
#  6   2020                189 non-null    float64
#  7   2021                189 non-null    float64
#  8   2022                189 non-null    float64
#  9   2023                189 non-null    float64
#  10  2024                180 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 16.4+ KB

# %%
#Gathering the datatypes of the Undernourished_People Table
Undernourished_People.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   COUNTRY_NAME        120 non-null    object
#  1   INDICATOR_LABEL     120 non-null    object
#  2   UNIT_MEASURE_LABEL  120 non-null    object
#  3   2017                96 non-null     float64
#  4   2018                96 non-null     float64
#  5   2019                95 non-null     float64
#  6   2020                94 non-null     float64
#  7   2021                97 non-null     float64
#  8   2022                94 non-null     float64
#  9   2023                94 non-null     float64
#  10  2024                91 non-null     float64
# dtypes: float64(8), object(3)
# memory usage: 10.4+ KB

# %%
#Gathering the datatypes of the Unable_To_Afford Table
Unable_To_Afford.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   COUNTRY_NAME        146 non-null    object
#  1   INDICATOR_LABEL     146 non-null    object
#  2   UNIT_MEASURE_LABEL  146 non-null    object
#  3   2017                145 non-null    float64
#  4   2018                142 non-null    float64
#  5   2019                140 non-null    float64
#  6   2020                139 non-null    float64
#  7   2021                139 non-null    float64
#  8   2022                139 non-null    float64
#  9   2023                141 non-null    float64
#  10  2024                137 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 12.7+ KB

# %%
#Checking duplicate values for each datasets
DietCost.duplicated().sum()
# Out:
# 0

# %%
GDP_Per_Capita.duplicated().sum()
# Out:
# 0

# %%
Undernourished_People.duplicated().sum()
# Out:
# 0

# %%
Unable_To_Afford.duplicated().sum()
# Out:
# 0

# %%
#Checking duplicate values for colomns
DietCost.duplicated(subset=['COUNTRY_NAME']).sum()
# Out:
# 0

# %%
GDP_Per_Capita.duplicated(subset=['COUNTRY_NAME']).sum()
# Out:
# 0

# %%
Undernourished_People.duplicated(subset=['COUNTRY_NAME']).sum()
# Out:
# 0

# %%
Unable_To_Afford.duplicated(subset=['COUNTRY_NAME']).sum()
# Out:
# 0

# %%
DietCost['COUNTRY_NAME'].unique()
# Out:
# array(['Aruba', 'Angola', 'Albania', 'United Arab Emirates', 'Argentina',
#        'Armenia', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Curacao', 'Cayman Islands', 'Cyprus', 'Czechia', 'Germany',
#        'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria',
#        'Ecuador', 'Egypt, Arab Rep.', 'Spain', 'Estonia', 'Ethiopia',
#        'Finland', 'Fiji', 'France', 'Gabon', 'United Kingdom', 'Ghana',
#        'Guinea', 'Gambia, The', 'Guinea-Bissau', 'Equatorial Guinea',
# ...

# %%
GDP_Per_Capita['COUNTRY_NAME'].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica', 'Cyprus',
#        'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt, Arab Rep.',
#        'Spain', 'Estonia', 'Ethiopia', 'Finland', 'Fiji', 'France',
#        'Micronesia, Fed. Sts.', 'Gabon', 'United Kingdom', 'Georgia',
# ...

# %%
Undernourished_People['COUNTRY_NAME'].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'United Arab Emirates',
#        'Argentina', 'Armenia', 'Azerbaijan', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bosnia and Herzegovina', 'Belarus',
#        'Bolivia', 'Brazil', 'Botswana', 'Central African Republic',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Costa Rica', 'Djibouti',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt, Arab Rep.',
#        'Ethiopia', 'Gabon', 'Georgia', 'Ghana', 'Guinea', 'Gambia, The',
#        'Guinea-Bissau', 'Guatemala', 'Hong Kong SAR, China', 'Honduras',
#        'Croatia', 'Haiti', 'Hungary', 'Indonesia', 'India',
#        'Iran, Islamic Rep.', 'Iraq', 'Jamaica', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kyrgyz Republic', 'Cambodia', 'Korea, Rep.', 'Lebanon',
#        'Liberia', 'Libya', 'Sri Lanka', 'Latvia', 'Morocco', 'Moldova',
# ...

# %%
Unable_To_Afford['COUNTRY_NAME'].unique()
# Out:
# array(['Angola', 'Albania', 'United Arab Emirates', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Burundi',
#        'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bulgaria',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bolivia', 'Brazil',
#        'Bhutan', 'Botswana', 'Central African Republic', 'Canada',
#        'Switzerland', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros',
#        'Cabo Verde', 'Costa Rica', 'Cyprus', 'Czechia', 'Germany',
#        'Djibouti', 'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador',
#        'Egypt, Arab Rep.', 'Spain', 'Estonia', 'Ethiopia', 'Finland',
#        'Fiji', 'France', 'Gabon', 'United Kingdom', 'Ghana', 'Guinea',
#        'Gambia, The', 'Guinea-Bissau', 'Greece', 'Guatemala', 'Guyana',
#        'Honduras', 'Croatia', 'Haiti', 'Hungary', 'Indonesia', 'India',
#        'Ireland', 'Iran, Islamic Rep.', 'Iraq', 'Israel', 'Italy',
# ...

# %%
target_countries = ["Botswana", "Eswatini", "Zambia", "Namibia", "South Africa"]

filtered_DietCost = DietCost[DietCost["COUNTRY_NAME"].isin(target_countries)]

# Display the filtered data
print(filtered)
# Out:
#    COUNTRY_NAME                                    INDICATOR_LABEL  \
# 0      Botswana  Number of people unable to afford a healthy di...
# 1       Namibia  Number of people unable to afford a healthy di...
# 2      Eswatini  Number of people unable to afford a healthy di...
# 3  South Africa  Number of people unable to afford a healthy di...
# 4        Zambia  Number of people unable to afford a healthy di...
#
#   UNIT_MEASURE_LABEL  2017  2018  2019  2020  2021  2022  2023  2024
# 0            Persons   1.4   1.4   1.4   1.4   1.5   1.5   1.5   1.5
# 1            Persons   1.4   1.5   1.5   1.7   1.7   1.6   1.7   1.7
# 2            Persons   0.8   0.8   0.8   0.8   0.8   0.8   0.8   0.8
# 3            Persons  35.0  35.3  35.9  37.4  37.6  38.1  39.0  39.5
# 4            Persons  13.6  14.0  14.6  15.3  15.9  16.5  17.0  17.5

# %%
desc_stats = filtered_DietCost.describe()
print("descriptive statistics:\n", desc_stats)

#COME BACK AND WRITE INSIGHTS
# Out:
# descriptive statistics:
#             2017      2018      2019      2020      2021      2022
# count  5.000000  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   3.110000  3.116000  3.168000  3.240000  3.432000  3.736000
# std    0.244847  0.214663  0.208974  0.230543  0.223652  0.252646
# min    2.730000  2.790000  2.880000  2.920000  3.200000  3.530000
# 25%    3.050000  3.080000  3.100000  3.190000  3.310000  3.560000
# 50%    3.130000  3.090000  3.120000  3.200000  3.390000  3.690000
# 75%    3.280000  3.290000  3.330000  3.340000  3.470000  3.740000
# max    3.360000  3.330000  3.410000  3.550000  3.790000  4.160000

# %%
target_countries = ["Botswana", "Eswatini", "Zambia", "Namibia", "South Africa"]

filtered_GDP = GDP_Per_Capita[GDP_Per_Capita["COUNTRY_NAME"].isin(target_countries)]

# Display the filtered data
print(filtered)
# Out:
#    COUNTRY_NAME                                    INDICATOR_LABEL  \
# 0      Botswana  Number of people unable to afford a healthy di...
# 1       Namibia  Number of people unable to afford a healthy di...
# 2      Eswatini  Number of people unable to afford a healthy di...
# 3  South Africa  Number of people unable to afford a healthy di...
# 4        Zambia  Number of people unable to afford a healthy di...
#
#   UNIT_MEASURE_LABEL  2017  2018  2019  2020  2021  2022  2023  2024
# 0            Persons   1.4   1.4   1.4   1.4   1.5   1.5   1.5   1.5
# 1            Persons   1.4   1.5   1.5   1.7   1.7   1.6   1.7   1.7
# 2            Persons   0.8   0.8   0.8   0.8   0.8   0.8   0.8   0.8
# 3            Persons  35.0  35.3  35.9  37.4  37.6  38.1  39.0  39.5
# 4            Persons  13.6  14.0  14.6  15.3  15.9  16.5  17.0  17.5

# %%
desc_stats = filtered_GDP.describe()
print("descriptive statistics:\n", desc_stats)

#COME BACK AND WRITE INSIGHTS
# Out:
# descriptive statistics:
#                 2017          2018          2019          2020          2021  \
# count      5.000000      5.000000      5.000000      5.000000      5.000000
# mean   11332.420000  11378.000000  11400.880000  10465.500000  10966.000000
# std     5223.648643   5352.675877   5402.263658   4822.117144   5356.716995
# min     3612.500000   3647.000000   3591.600000   3391.600000   3503.000000
# 25%     9696.600000   9632.200000  10123.300000   9652.200000   9709.100000
# 50%    11408.700000  11214.400000  10813.300000   9727.500000   9946.000000
# 75%    14591.400000  14571.400000  14370.200000  13266.800000  13711.300000
# max    17352.900000  17825.000000  18106.000000  16289.400000  17960.600000
#
#                2022          2023          2024
# count      5.000000      5.000000      5.000000
# mean   11183.700000  11327.140000  11206.380000
# std     5549.642832   5583.151252   5255.425414
# min     3585.100000   3673.500000   3716.000000
# ...

# %%
target_countries = ["Botswana", "Eswatini", "Zambia", "Namibia", "South Africa"]

filtered_Undernourished = Undernourished_People[Undernourished_People["COUNTRY_NAME"].isin(target_countries)]

# Display the filtered data
print(filtered)
# Out:
#    COUNTRY_NAME                                    INDICATOR_LABEL  \
# 0      Botswana  Number of people unable to afford a healthy di...
# 1       Namibia  Number of people unable to afford a healthy di...
# 2      Eswatini  Number of people unable to afford a healthy di...
# 3  South Africa  Number of people unable to afford a healthy di...
# 4        Zambia  Number of people unable to afford a healthy di...
#
#   UNIT_MEASURE_LABEL  2017  2018  2019  2020  2021  2022  2023  2024
# 0            Persons   1.4   1.4   1.4   1.4   1.5   1.5   1.5   1.5
# 1            Persons   1.4   1.5   1.5   1.7   1.7   1.6   1.7   1.7
# 2            Persons   0.8   0.8   0.8   0.8   0.8   0.8   0.8   0.8
# 3            Persons  35.0  35.3  35.9  37.4  37.6  38.1  39.0  39.5
# 4            Persons  13.6  14.0  14.6  15.3  15.9  16.5  17.0  17.5

# %%
desc_stats = filtered_Undernourished.describe()
print("descriptive statistics:\n", desc_stats)

#COME BACK AND WRITE INSIGHTS
# Out:
# descriptive statistics:
#             2017      2018      2019      2020      2021      2022      2023  \
# count  5.000000  5.000000  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   2.120000  2.040000  2.120000  2.260000  2.560000  2.800000  2.960000
# std    2.462113  2.357541  2.462113  2.658571  3.042696  3.318885  3.484681
# min    0.200000  0.200000  0.200000  0.100000  0.100000  0.100000  0.200000
# 25%    0.500000  0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 50%    0.500000  0.500000  0.500000  0.500000  0.500000  0.600000  0.600000
# 75%    3.700000  3.500000  3.700000  4.300000  5.200000  5.800000  6.200000
# max    5.700000  5.500000  5.700000  5.900000  6.500000  7.000000  7.300000
#
#            2024
# count  5.000000
# mean   3.060000
# std    3.633593
# min    0.200000
# 25%    0.500000
# 50%    0.600000
# 75%    6.300000
# max    7.700000

# %%
target_countries = ["Botswana", "Eswatini", "Zambia", "Namibia", "South Africa"]

filtered_Unaffordability = Unable_To_Afford[Unable_To_Afford["COUNTRY_NAME"].isin(target_countries)]

# Display the filtered data
print(filtered)
# Out:
#    COUNTRY_NAME                                    INDICATOR_LABEL  \
# 0      Botswana  Number of people unable to afford a healthy di...
# 1       Namibia  Number of people unable to afford a healthy di...
# 2      Eswatini  Number of people unable to afford a healthy di...
# 3  South Africa  Number of people unable to afford a healthy di...
# 4        Zambia  Number of people unable to afford a healthy di...
#
#   UNIT_MEASURE_LABEL  2017  2018  2019  2020  2021  2022  2023  2024
# 0            Persons   1.4   1.4   1.4   1.4   1.5   1.5   1.5   1.5
# 1            Persons   1.4   1.5   1.5   1.7   1.7   1.6   1.7   1.7
# 2            Persons   0.8   0.8   0.8   0.8   0.8   0.8   0.8   0.8
# 3            Persons  35.0  35.3  35.9  37.4  37.6  38.1  39.0  39.5
# 4            Persons  13.6  14.0  14.6  15.3  15.9  16.5  17.0  17.5

# %%
desc_stats = filtered_Unaffordability.describe()
print("descriptive statistics:\n", desc_stats)

#COME BACK AND WRITE INSIGHTS
# Out:
# descriptive statistics:
#              2017       2018       2019       2020       2021       2022  \
# count   5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   10.440000  10.600000  10.840000  11.320000  11.500000  11.700000
# std    14.744084  14.875651  15.159914  15.792625  15.898899  16.162147
# min     0.800000   0.800000   0.800000   0.800000   0.800000   0.800000
# 25%     1.400000   1.400000   1.400000   1.400000   1.500000   1.500000
# 50%     1.400000   1.500000   1.500000   1.700000   1.700000   1.600000
# 75%    13.600000  14.000000  14.600000  15.300000  15.900000  16.500000
# max    35.000000  35.300000  35.900000  37.400000  37.600000  38.100000
#
#             2023       2024
# count   5.000000   5.000000
# mean   12.000000  12.200000
# std    16.551284  16.793451
# min     0.800000   0.800000
# 25%     1.500000   1.500000
# 50%     1.700000   1.700000
# 75%    17.000000  17.500000
# max    39.000000  39.500000
